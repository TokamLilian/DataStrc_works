# %% [markdown]
# # $\text{Data Structures} $

# %% [markdown]
# ### Binary Search Tree

# %% [markdown]
# #### Basic Operations:

# %% [markdown]
# - create(T, n, max) : Create priority queue from an array T [1, n]
# - size(p) : Number of elmts in queue p
# - top(p) : Most prior ekement of queue p
# - deleteTop(p) : Delete most prior element (call top and remove it)
# - insert(p, x) : Insert element x in the queue p
# - edit(p, i, x') : Edit element i to become x (optional)

# %%
n = 1#
T = [1]#
max = 2

def create(T, n, max):
#consntat
    if n>max or n<0 or max <0 : 
        return "error" 
    
def size(p):
#constant
    return n

def top(p):
#O(n)
    if n == 0 : return "error"
    n = T[1]
    for i in range(2, n) :
        if T[i] * p > n*p :   #* means the array of the queue object
            n = T[i]

    return n

def insert(p, x):
#constant
    if n >= max : return "error"
    n += 1
    T[n] = x

def deleteTop(p):
#O(n)
    if n == 0 : return "error"
    for i in range(2, n) :
        if T[i] * p < T[i-1] * p : 
            temp = T[i]
            T[i] = T[i-1]
            T[i-1] = temp
    n -= 1

def edit(P, i, x):
#constant
    if i<1 or i>n: return "error"
    T[i] = x

# %% [markdown]
# Sorted array:
#     Elmts of T are sorted in increasing order
#
# ```py
# def sort(T):
#     pass
#
# def create(T, n, max):
# #O(nlogn)
#     if n>max or n<0 or max <0 :
#         return "error"
#
#     sort(T)
#
# def size(p):
# #constant
#     return n
#
# def top(p):
# #constant
#     if n == 0 : return "error"
#     return T[n]         # Because the array is sorted
#
# def insert(p, x):
# #O(n)
#     if n >= max : return "error"
#     i = n
#     while i>0:          # Go through every element one-by-one, and insert a whole after each, the fill the whole
#         while T[i].p > x.p:
#             T[i+1] = T[i]
#             i -= 1
#     T[i+1] = x
#     n += 1
#
# def deleteTop(p):
# #constant
#     if n == 0 : return "error"
#     n -= 1              # Change the pointer of the top to the next element
#
# def edit(P, i, x):
# #O(n)
#     if i<1 or i>n: return "error"
#     T[i] = x
#     if x.p <= T[i+1] or x.p >= T[i+1]:
#         continue
#     else:
#         while i>0:          # Go through every element one-by-one to put the element at the correct position
#             while T[i].p > x.p:
#                 T[i+1] = T[i]
#                 i -= 1
#         T[i+1] = x
#
# ```

# %% [markdown]
# Heap: Complete Binary Tree with possible leaf is as bottom far left, adjacent nodes have same depth $\\$
# ![image.png](attachment:image.png)
#
# Indices :
# - $\text{Left Child Node index} = 2* \text{Parent node}$
# - $\text{Right Child Node index} = 2* \text{Parent node} + 1$
# - $\text{Parent Node} = \text{Child node index} // 2$ where "//" is integer division
#
# Properties :
# x is an internal node if it's priority >= Priority of both it's children, unless right child > n

# %%
T_array = []

def swap(a, b):
    temp = a
    a = b
    b = temp

def Heapify(T):
    k = n
    j = n
    while j>0          # repeat j times
        if j>1 and T[j//2].priority < T[k].priority:            # if j > 1 then it's not the root, look a the parent
            k = j//2
        swap (T[j], T[k])

        if j == k : break
        j -= 1

def HeapSort(T):
#O(nlog n) or O(log n !)
    i = n
    while i > 0:
        swap(T[i], T[1])                    ## correct this
        i -= 1

def sort(T):
    #if T.isSorted(): return
    HeapSort(T)

def create(T, n, max):
#O(n)
    if n>max or n<0 or max <0 : 
        return "error" 
    
    # behave as we had an empty heap, add each element of the heap from bottom to top,
    # build sub heaps then buil bigger heaps
    # TODO:

def size(p):
#constant
    return n

def top(p):
#constant
    if n == 0 : return "error"
    return T[1]         # Because the max heap is built

def deleteTop(p):
#O(log n)
    if n == 0 : return "error"
    T[1] = T[n]         # smallest element becomes the top
    n -= 1              # decrement the pointer of last element (number of elements has reduced)
    Heapify(T)           # rebuild the heap

def insert(p, x):
#O(log n)
    if n >= max : return "error"
    n = n + 1
    T[n] = x
    k = n
    j = k

    while j>0          # repeat j times
        if j>1 and T[j//2].priority < T[k].priority:            # if j > 1 then it's not the root, look a the parent
            k = j//2
        swap (T[j], T[k])

        if j == k : break
        j -= 1

def edit(P, i, x):
#O(log n)
    if i<1 or i>n: return "error"
    T[i] = x
    if x.p <= T[i+1] or x.p >= T[i+1]:
        continue
    else:
        while i>0:          # Go through every element one-by-one to put the element at the correct position
            while T[i].p > x.p:
                T[i+1] = T[i]
                i -= 1
        T[i+1] = x

class Node:
    def __init__:
        priority = None
        value = None

class T:
    def __init__:
        queue = None

    def add():
        pass

    def isSorted():
        pass
